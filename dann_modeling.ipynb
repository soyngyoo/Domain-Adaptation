# %%
import random,os,csv,glob,math,logging
import json
import numpy as np
import pandas as pd
import time

import cv2 as cv
from sklearn.manifold import TSNE
import scipy.io as sio
from os.path import dirname, join as pjoin
import scipy.io as sio

from matplotlib import pyplot as plt
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d
import tqdm
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils import shuffle
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.metrics import r2_score

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Reshape, Concatenate,LeakyReLU,Input, Dropout,Lambda,Activation, BatchNormalization
from tensorflow.keras.layers import MaxPooling1D,Conv1D,GlobalAveragePooling1D,multiply
from tensorflow.keras.layers import Conv3D, MaxPooling3D

from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras import metrics
from tensorflow.keras import models, layers, optimizers  
from tensorflow.keras.callbacks import TensorBoard  
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.utils import plot_model

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def plot_embedding(X, y, d, title=None):
    """Plot an embedding X with the class label y colored by the domain d."""
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    # Plot colors numbers
    plt.figure(figsize=(5,5))
    ax = plt.subplot(111)
    for i in tqdm(range(X.shape[0])):
        # plot colored number
        if d[i] == 0:
            color = 'green'
        elif d[i] == 1:
            color = 'purple'
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=color,
                 fontdict={'weight': 'bold', 'size': 9})
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
def voxel_load1(path,names):
    vox_list=[]
    for i in tqdm.tqdm(range(len(names))):
        vox = np.load(path+names[i]+'.npz')
        voxel = vox['x']
        if voxel.shape[0] == 32:
            voxel[:,:,:10]=0
        else:
            voxel[:,:,:20]=0
        vox_list.append(voxel)
    vox_list = np.asarray(vox_list)
    vox_sp = vox_list.shape
    vox_list = vox_list.reshape(vox_sp[0],vox_sp[1],vox_sp[2],vox_sp[3],1)
    print(np.shape(vox_list))
    return vox_list

def voxel_load2(path,names):
    vox_list=[]
    for i in tqdm.tqdm(range(len(names))):
        mat_contents = sio.loadmat(path+names[i]+'.mat')
        voxel = mat_contents['Volume1']
        if voxel.shape[0] == 32:
            voxel[:,:,:10]=0
        else:
            voxel[:,:,:20]=0
        vox_list.append(voxel)
        
    vox_list = np.asarray(vox_list)
    vox_sp = vox_list.shape
    vox_list = vox_list.reshape(vox_sp[0],vox_sp[1],vox_sp[2],vox_sp[3],1)
    print(np.shape(vox_list))
    return vox_list

def df_load(df_path,df_type):
    df = pd.read_csv(df_path)
    data = df[df_type]
    data = np.asarray(data)
    print(df_type,data.shape)
    return data

# %%
src = '/content/drive/MyDrive/2020 대한기계학회(본부)/Dataset/WHEEL_data/'

# %%
df_concept = pd.read_csv(src+'LABEL/concept/concept_label.csv')
df_detailed = pd.read_csv(src+'LABEL/chassis/chassis_label.csv')

# %%
concept_names = df_concept['name']
concept_stiff = np.array(df_concept['stiffness(n/m)'])

detailed_names = df_detailed['name']
detailed_stiff = np.array(df_detailed['stiffness(n/m)'])

# %%
stiff = np.concatenate([concept_stiff,detailed_stiff])

# %%
scaler = MinMaxScaler()
scaler.fit(stiff.reshape(-1,1))
concept_stiff_sc = scaler.transform(concept_stiff.reshape((-1, 1)))
detailed_stiff_sc = scaler.transform(detailed_stiff.reshape(-1, 1))

# %%
plt.hist(concept_stiff)
plt.hist(detailed_stiff)
# Out:
# (array([ 1.,  2.,  7.,  8.,  9., 13.,  9.,  7.,  7.,  2.]),
#  array([2.05818745e+08, 2.29551030e+08, 2.53283314e+08, 2.77015599e+08,
#         3.00747884e+08, 3.24480169e+08, 3.48212454e+08, 3.71944739e+08,
#         3.95677024e+08, 4.19409308e+08, 4.43141593e+08]),
#  <a list of 10 Patch objects>)

# %%
src2 = src+'INPUT/'
vox32_concept  = voxel_load1(src2+'concept/Voxel_32/',concept_names)
vox32_detailed = voxel_load2(src2+'chassis/voxel_32/',detailed_names)
# Out:
# 100%|██████████| 1102/1102 [07:06<00:00,  2.58it/s]
#   0%|          | 0/65 [00:00<?, ?it/s]
# (1102, 32, 32, 32, 1)
# 100%|██████████| 65/65 [00:39<00:00,  1.63it/s]
# (65, 32, 32, 32, 1)

# %%
trainX = vox32_concept[:990]
trainY = concept_stiff_sc[:990]
testX = vox32_concept[990:]
testY = concept_stiff_sc[990:]

trainDX = vox32_detailed[:50]
trainDY = detailed_stiff_sc[:50]
testDX = vox32_detailed[50:]
testDY = detailed_stiff_sc[50:]

# %%
plt.hist(trainY,alpha = 0.5)
plt.hist(testY,alpha = 0.5)
plt.show()

plt.hist(trainDY,alpha = 0.5)
plt.hist(testDY,alpha = 0.5)
plt.show()

# %%
combined_train_imgs = np.concatenate([trainX, trainDX])
combined_train_labels = np.concatenate([trainY, trainDY])
combined_train_domain = np.concatenate([np.tile([1., 0.], [len(trainX), 1]),
                                        np.tile([0., 1.], [len(trainDX), 1])])
print(combined_train_imgs.shape,combined_train_labels.shape,combined_train_domain.shape)
# Out:
# (1040, 32, 32, 32, 1) (1040, 1) (1040, 2)

# %%
combined_test_imgs = np.concatenate([testX, testDX])
combined_test_labels = np.concatenate([testY, testDY])
combined_test_domain = np.concatenate([np.tile([1., 0.], [len(testX), 1]),
                                        np.tile([0., 1.], [len(testDX), 1])])

print(combined_test_imgs.shape,combined_test_labels.shape,combined_test_domain.shape)
# Out:
# (127, 32, 32, 32, 1) (127, 1) (127, 2)

# %%
def BLOCK(input_a,c):
    added = Dense(c,
                  use_bias=True, 
                  kernel_initializer='glorot_normal',
                  bias_initializer='zeros', kernel_regularizer=None)(input_a)
    added = BatchNormalization()(added)
    return LeakyReLU(alpha=0.1)(added)
def feature_extractor(inp):
    x1 = Conv3D(16,(3,3,3),use_bias=True, kernel_initializer='glorot_normal', 
                  bias_initializer='zeros', kernel_regularizer=None,name='conv1')(inp)
    x1 = BatchNormalization()(x1)
    x1 = LeakyReLU(alpha=0.1)(x1)
    x1 = Conv3D(16,(3,3,3),use_bias=True, kernel_initializer='glorot_normal', 
                  bias_initializer='zeros', kernel_regularizer=None,name='conv2')(x1)
    x1 = BatchNormalization()(x1)
    x1 = LeakyReLU(alpha=0.1)(x1)
    x1 = MaxPooling3D((2,2,2),name='maxpooling1')(x1)
    x1 = Dropout(rate=0.3)(x1)
    x1 = Conv3D(32,(3,3,3),use_bias=True, kernel_initializer='glorot_normal', 
                  bias_initializer='zeros', kernel_regularizer=None,name='conv3')(x1)
    x1 = BatchNormalization()(x1)
    x1 = LeakyReLU(alpha=0.1)(x1)
    x1 = Conv3D(32,(3,3,3),use_bias=True, kernel_initializer='glorot_normal', 
                  bias_initializer='zeros', kernel_regularizer=None,name='conv4')(x1)
    x1 = BatchNormalization()(x1)
    x1 = LeakyReLU(alpha=0.1)(x1)
    x1 = MaxPooling3D((2,2,2),name='maxpooling2')(x1)
    x1 = Dropout(rate=0.3)(x1)
    x1 = Conv3D(64,(3,3,3),use_bias=True, kernel_initializer='glorot_normal', 
                  bias_initializer='zeros', kernel_regularizer=None,name='conv5')(x1)
    x1 = BatchNormalization()(x1)
    x1 = LeakyReLU(alpha=0.1)(x1)
    x1 = Flatten()(x1)
    return x1

def regressor(inp):
    added = BLOCK(inp,2000)
    added = BLOCK(added,300)
    added = BLOCK(added,150)
    added = BLOCK(added,20)
    added = BLOCK(added,16)
    out = Dense(1,name='regressor_output')(added)
    return out
def discriminator(inp):
    out = Dense(100, activation="relu")(inp)
    discriminator_output = Dense(2, activation="softmax", name="discriminator_output")(out)
    return discriminator_output
    
def cnn():
    inp =  Input(shape=(32,32,32,1))
    feature_output = feature_extractor(inp)
    regressor_output = regressor(feature_output)
    model = Model(inputs=inp, outputs=regressor_output)
    return model

@tf.custom_gradient
def GradientReversalOperator(x):
	def grad(dy):
		return -1 * dy
	return x, grad

class GradientReversalLayer(tf.keras.layers.Layer):
	def __init__(self):
		super(GradientReversalLayer, self).__init__()
		
	def call(self, inputs):
		return GradientReversalOperator(inputs)
  
def dann():
    inp =  Input(shape=(32,32,32,1))
    feature_output = feature_extractor(inp)
    regressor_output = regressor(feature_output)

    grl_layer = GradientReversalLayer()(feature_output)
    discriminator_output = discriminator(grl_layer)
    model = tf.keras.models.Model(inputs=inp, outputs=[discriminator_output,regressor_output])
    return model

# %%
def mape(y_true, y_pred): 
    return K.mean(K.abs((y_true - y_pred) / y_true))*100
    
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

def mape2(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true))*100
    
def rmse2(y_true, y_pred):
    return np.sqrt(np.mean(np.square(y_pred - y_true)))

def R2(y_true,y_pred):
    SSE = np.mean(np.square(y_true - y_pred))
    SSR = np.mean(np.square(y_true - np.var(y_true)))
    result = 1 - (SSE/SSR)
    return result

def mkdir(model_dir):
    if not os.path.exists(model_dir):
        os.mkdir(model_dir)

# %%
def training(model,model_name,dataset,loss):
  #hyperparameters
  lr= 0.0001
  bata_1= 0.9
  batch_size= 64
  epochs= 1000
  patience = 500
  loss = loss
  savename =  model_dir+model_name+".h5"

  if 'dann' in model_name:
    cp_callback = ModelCheckpoint(filepath = savename
                                  ,monitor='val_regressor_output_loss'
                                  ,save_best_only=True
                                  ,save_weights_only=True)

    early_stopping = EarlyStopping(monitor='val_regressor_output_loss'
                                  ,patience=patience)
    model.compile(optimizer=Adam(lr=lr)
                  ,loss={'regressor_output': loss
                         ,'discriminator_output': 'binary_crossentropy'})
  else:
    cp_callback = ModelCheckpoint(filepath = savename
                                ,monitor='val_loss'
                                ,save_best_only=True
                                ,save_weights_only=False)

    early_stopping = EarlyStopping(monitor='val_loss'
                                ,patience=patience)
    model.compile(loss=loss,optimizer=Adam(lr=lr))
  
  startTime = time.time()

  #x_train,y_train = combined_train_imgs,combined_train_labels
  x_train,y_train,x_test,y_test = dataset
  #x_valid,y_valid = combined_test_imgs,combined_test_labels

  hist = model.fit(x_train,y_train
                  ,batch_size=batch_size
                  ,epochs= epochs
                  ,verbose= 1
                  ,validation_data =(x_valid,y_valid)
                  ,callbacks=[cp_callback, early_stopping])

  endTime = time.time() - startTime
  print("end time:",round(endTime,2))
  return model

# %%
model_dir = './model_checkpoint/'
model_name = 'source_only_model'
mkdir(model_dir)
dataset = trainX,trainY,testX,testY
source_only_model = training(cnn(),
                             model_name,
                             dataset,
                             'mse')

# %%
model_name = 'source_add_target'
mkdir(model_dir)
dataset = (combined_train_imgs,combined_train_labels
           ,combined_test_imgs,combined_test_labels)
source_add_target_model = training(cnn(),
                             model_name,
                             dataset,
                             'mse')

# %%
model_name = 'dann'

dataset = (combined_train_imgs,[combined_train_domain,combined_train_labels]
          ,combined_test_imgs,[combined_test_domain,combined_test_labels])

dann_model = training(dann(),
                      model_name,
                      dataset,
                      'mse')
# Out:
# Epoch 1/1000
#  2/17 [==>...........................] - ETA: 1s - loss: 0.8047 - discriminator_output_loss: 0.2694 - regressor_output_loss: 0.5354WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0483s vs `on_train_batch_end` time: 0.1119s). Check your callbacks.
# 17/17 [==============================] - 3s 156ms/step - loss: 0.8666 - discriminator_output_loss: 0.2500 - regressor_output_loss: 0.6167 - val_loss: 1.0105 - val_discriminator_output_loss: 0.7050 - val_regressor_output_loss: 0.3055
# Epoch 2/1000
# 17/17 [==============================] - 2s 139ms/step - loss: 0.7138 - discriminator_output_loss: 0.2247 - regressor_output_loss: 0.4891 - val_loss: 1.0321 - val_discriminator_output_loss: 0.7362 - val_regressor_output_loss: 0.2959
# Epoch 3/1000
# 17/17 [==============================] - 2s 138ms/step - loss: 0.6419 - discriminator_output_loss: 0.2014 - regressor_output_loss: 0.4405 - val_loss: 1.0782 - val_discriminator_output_loss: 0.7942 - val_regressor_output_loss: 0.2839
# Epoch 4/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.6069 - discriminator_output_loss: 0.2075 - regressor_output_loss: 0.3994 - val_loss: 1.1437 - val_discriminator_output_loss: 0.8594 - val_regressor_output_loss: 0.2844
# Epoch 5/1000
# 17/17 [==============================] - 2s 140ms/step - loss: 0.5607 - discriminator_output_loss: 0.1753 - regressor_output_loss: 0.3854 - val_loss: 1.1667 - val_discriminator_output_loss: 0.8994 - val_regressor_output_loss: 0.2673
# Epoch 6/1000
# 17/17 [==============================] - 2s 136ms/step - loss: 0.4759 - discriminator_output_loss: 0.1850 - regressor_output_loss: 0.2909 - val_loss: 1.2581 - val_discriminator_output_loss: 0.9599 - val_regressor_output_loss: 0.2982
# Epoch 7/1000
# 17/17 [==============================] - 2s 136ms/step - loss: 0.4430 - discriminator_output_loss: 0.1610 - regressor_output_loss: 0.2820 - val_loss: 1.3414 - val_discriminator_output_loss: 1.0260 - val_regressor_output_loss: 0.3153
# Epoch 8/1000
# 17/17 [==============================] - 2s 135ms/step - loss: 0.4041 - discriminator_output_loss: 0.1569 - regressor_output_loss: 0.2472 - val_loss: 1.3751 - val_discriminator_output_loss: 1.0739 - val_regressor_output_loss: 0.3013
# Epoch 9/1000
# 17/17 [==============================] - 2s 140ms/step - loss: 0.3940 - discriminator_output_loss: 0.1483 - regressor_output_loss: 0.2458 - val_loss: 1.4589 - val_discriminator_output_loss: 1.2009 - val_regressor_output_loss: 0.2580
# Epoch 10/1000
# 17/17 [==============================] - 2s 140ms/step - loss: 0.3735 - discriminator_output_loss: 0.1457 - regressor_output_loss: 0.2278 - val_loss: 1.5180 - val_discriminator_output_loss: 1.3407 - val_regressor_output_loss: 0.1773
# Epoch 11/1000
# 17/17 [==============================] - 2s 139ms/step - loss: 0.3565 - discriminator_output_loss: 0.1426 - regressor_output_loss: 0.2138 - val_loss: 1.5045 - val_discriminator_output_loss: 1.3702 - val_regressor_output_loss: 0.1343
# Epoch 12/1000
# 17/17 [==============================] - 2s 138ms/step - loss: 0.3137 - discriminator_output_loss: 0.1265 - regressor_output_loss: 0.1872 - val_loss: 1.6361 - val_discriminator_output_loss: 1.5238 - val_regressor_output_loss: 0.1123
# Epoch 13/1000
# 17/17 [==============================] - 2s 138ms/step - loss: 0.3062 - discriminator_output_loss: 0.1325 - regressor_output_loss: 0.1736 - val_loss: 1.6670 - val_discriminator_output_loss: 1.5691 - val_regressor_output_loss: 0.0979
# Epoch 14/1000
# 17/17 [==============================] - 2s 138ms/step - loss: 0.3062 - discriminator_output_loss: 0.1190 - regressor_output_loss: 0.1872 - val_loss: 1.7447 - val_discriminator_output_loss: 1.6678 - val_regressor_output_loss: 0.0768
# Epoch 15/1000
# 17/17 [==============================] - 2s 138ms/step - loss: 0.2857 - discriminator_output_loss: 0.1235 - regressor_output_loss: 0.1622 - val_loss: 1.6738 - val_discriminator_output_loss: 1.6103 - val_regressor_output_loss: 0.0635
# Epoch 16/1000
# 17/17 [==============================] - 2s 137ms/step - loss: 0.2754 - discriminator_output_loss: 0.1196 - regressor_output_loss: 0.1558 - val_loss: 1.7490 - val_discriminator_output_loss: 1.7138 - val_regressor_output_loss: 0.0352
# Epoch 17/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2492 - discriminator_output_loss: 0.1124 - regressor_output_loss: 0.1368 - val_loss: 1.7531 - val_discriminator_output_loss: 1.7166 - val_regressor_output_loss: 0.0366
# Epoch 18/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2564 - discriminator_output_loss: 0.1104 - regressor_output_loss: 0.1460 - val_loss: 1.7539 - val_discriminator_output_loss: 1.7015 - val_regressor_output_loss: 0.0524
# Epoch 19/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2495 - discriminator_output_loss: 0.1212 - regressor_output_loss: 0.1283 - val_loss: 1.8107 - val_discriminator_output_loss: 1.7511 - val_regressor_output_loss: 0.0596
# Epoch 20/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2527 - discriminator_output_loss: 0.1274 - regressor_output_loss: 0.1253 - val_loss: 1.6046 - val_discriminator_output_loss: 1.5275 - val_regressor_output_loss: 0.0771
# Epoch 21/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2610 - discriminator_output_loss: 0.1338 - regressor_output_loss: 0.1273 - val_loss: 1.7509 - val_discriminator_output_loss: 1.6448 - val_regressor_output_loss: 0.1061
# Epoch 22/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2553 - discriminator_output_loss: 0.1329 - regressor_output_loss: 0.1224 - val_loss: 1.7763 - val_discriminator_output_loss: 1.6869 - val_regressor_output_loss: 0.0894
# Epoch 23/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2614 - discriminator_output_loss: 0.1398 - regressor_output_loss: 0.1215 - val_loss: 1.6425 - val_discriminator_output_loss: 1.5805 - val_regressor_output_loss: 0.0620
# Epoch 24/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2541 - discriminator_output_loss: 0.1359 - regressor_output_loss: 0.1182 - val_loss: 1.7952 - val_discriminator_output_loss: 1.7423 - val_regressor_output_loss: 0.0529
# Epoch 25/1000
# 17/17 [==============================] - 2s 131ms/step - loss: 0.2635 - discriminator_output_loss: 0.1510 - regressor_output_loss: 0.1125 - val_loss: 1.6989 - val_discriminator_output_loss: 1.6529 - val_regressor_output_loss: 0.0460
# Epoch 26/1000
# 17/17 [==============================] - 2s 136ms/step - loss: 0.2412 - discriminator_output_loss: 0.1351 - regressor_output_loss: 0.1061 - val_loss: 1.6598 - val_discriminator_output_loss: 1.6311 - val_regressor_output_loss: 0.0288
# Epoch 27/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2516 - discriminator_output_loss: 0.1482 - regressor_output_loss: 0.1034 - val_loss: 1.7445 - val_discriminator_output_loss: 1.7143 - val_regressor_output_loss: 0.0302
# Epoch 28/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2622 - discriminator_output_loss: 0.1500 - regressor_output_loss: 0.1122 - val_loss: 1.7344 - val_discriminator_output_loss: 1.6947 - val_regressor_output_loss: 0.0397
# Epoch 29/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2511 - discriminator_output_loss: 0.1581 - regressor_output_loss: 0.0930 - val_loss: 1.7581 - val_discriminator_output_loss: 1.7130 - val_regressor_output_loss: 0.0451
# Epoch 30/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2669 - discriminator_output_loss: 0.1683 - regressor_output_loss: 0.0986 - val_loss: 1.7383 - val_discriminator_output_loss: 1.6929 - val_regressor_output_loss: 0.0454
# Epoch 31/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2510 - discriminator_output_loss: 0.1643 - regressor_output_loss: 0.0867 - val_loss: 1.8256 - val_discriminator_output_loss: 1.7800 - val_regressor_output_loss: 0.0456
# Epoch 32/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2421 - discriminator_output_loss: 0.1537 - regressor_output_loss: 0.0884 - val_loss: 1.7410 - val_discriminator_output_loss: 1.7035 - val_regressor_output_loss: 0.0375
# Epoch 33/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2609 - discriminator_output_loss: 0.1642 - regressor_output_loss: 0.0967 - val_loss: 1.6397 - val_discriminator_output_loss: 1.5993 - val_regressor_output_loss: 0.0405
# Epoch 34/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2672 - discriminator_output_loss: 0.1774 - regressor_output_loss: 0.0898 - val_loss: 1.7304 - val_discriminator_output_loss: 1.6858 - val_regressor_output_loss: 0.0447
# Epoch 35/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2518 - discriminator_output_loss: 0.1692 - regressor_output_loss: 0.0827 - val_loss: 1.6531 - val_discriminator_output_loss: 1.6031 - val_regressor_output_loss: 0.0500
# Epoch 36/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2696 - discriminator_output_loss: 0.1858 - regressor_output_loss: 0.0838 - val_loss: 1.6817 - val_discriminator_output_loss: 1.6207 - val_regressor_output_loss: 0.0611
# Epoch 37/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2612 - discriminator_output_loss: 0.1809 - regressor_output_loss: 0.0803 - val_loss: 1.7526 - val_discriminator_output_loss: 1.6756 - val_regressor_output_loss: 0.0770
# Epoch 38/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2442 - discriminator_output_loss: 0.1632 - regressor_output_loss: 0.0810 - val_loss: 1.6231 - val_discriminator_output_loss: 1.5482 - val_regressor_output_loss: 0.0749
# Epoch 39/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.2568 - discriminator_output_loss: 0.1849 - regressor_output_loss: 0.0719 - val_loss: 1.7366 - val_discriminator_output_loss: 1.6741 - val_regressor_output_loss: 0.0625
# Epoch 40/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2870 - discriminator_output_loss: 0.2016 - regressor_output_loss: 0.0855 - val_loss: 1.5934 - val_discriminator_output_loss: 1.5292 - val_regressor_output_loss: 0.0642
# Epoch 41/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2577 - discriminator_output_loss: 0.1825 - regressor_output_loss: 0.0752 - val_loss: 1.6811 - val_discriminator_output_loss: 1.5999 - val_regressor_output_loss: 0.0812
# Epoch 42/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.2546 - discriminator_output_loss: 0.1757 - regressor_output_loss: 0.0789 - val_loss: 1.4350 - val_discriminator_output_loss: 1.3480 - val_regressor_output_loss: 0.0870
# Epoch 43/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2640 - discriminator_output_loss: 0.1945 - regressor_output_loss: 0.0695 - val_loss: 1.4045 - val_discriminator_output_loss: 1.3335 - val_regressor_output_loss: 0.0710
# Epoch 44/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2655 - discriminator_output_loss: 0.1936 - regressor_output_loss: 0.0720 - val_loss: 1.5184 - val_discriminator_output_loss: 1.4797 - val_regressor_output_loss: 0.0387
# Epoch 45/1000
# 17/17 [==============================] - 2s 138ms/step - loss: 0.2620 - discriminator_output_loss: 0.1901 - regressor_output_loss: 0.0719 - val_loss: 1.3664 - val_discriminator_output_loss: 1.3417 - val_regressor_output_loss: 0.0247
# Epoch 46/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2572 - discriminator_output_loss: 0.1883 - regressor_output_loss: 0.0689 - val_loss: 1.4444 - val_discriminator_output_loss: 1.4194 - val_regressor_output_loss: 0.0250
# Epoch 47/1000
# 17/17 [==============================] - 2s 137ms/step - loss: 0.2734 - discriminator_output_loss: 0.1980 - regressor_output_loss: 0.0754 - val_loss: 1.3475 - val_discriminator_output_loss: 1.3303 - val_regressor_output_loss: 0.0172
# Epoch 48/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2721 - discriminator_output_loss: 0.2063 - regressor_output_loss: 0.0659 - val_loss: 1.5366 - val_discriminator_output_loss: 1.5146 - val_regressor_output_loss: 0.0220
# Epoch 49/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2699 - discriminator_output_loss: 0.2010 - regressor_output_loss: 0.0690 - val_loss: 1.3732 - val_discriminator_output_loss: 1.3536 - val_regressor_output_loss: 0.0196
# Epoch 50/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2811 - discriminator_output_loss: 0.2105 - regressor_output_loss: 0.0707 - val_loss: 1.4243 - val_discriminator_output_loss: 1.3999 - val_regressor_output_loss: 0.0244
# Epoch 51/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2628 - discriminator_output_loss: 0.1981 - regressor_output_loss: 0.0647 - val_loss: 1.3042 - val_discriminator_output_loss: 1.2730 - val_regressor_output_loss: 0.0312
# Epoch 52/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2785 - discriminator_output_loss: 0.2131 - regressor_output_loss: 0.0654 - val_loss: 1.1964 - val_discriminator_output_loss: 1.1603 - val_regressor_output_loss: 0.0361
# Epoch 53/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2654 - discriminator_output_loss: 0.2034 - regressor_output_loss: 0.0620 - val_loss: 1.2038 - val_discriminator_output_loss: 1.1604 - val_regressor_output_loss: 0.0434
# Epoch 54/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2612 - discriminator_output_loss: 0.1979 - regressor_output_loss: 0.0633 - val_loss: 1.2031 - val_discriminator_output_loss: 1.1574 - val_regressor_output_loss: 0.0456
# Epoch 55/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2669 - discriminator_output_loss: 0.2091 - regressor_output_loss: 0.0578 - val_loss: 1.1351 - val_discriminator_output_loss: 1.0851 - val_regressor_output_loss: 0.0501
# Epoch 56/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2668 - discriminator_output_loss: 0.2067 - regressor_output_loss: 0.0601 - val_loss: 1.0768 - val_discriminator_output_loss: 1.0275 - val_regressor_output_loss: 0.0493
# Epoch 57/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2601 - discriminator_output_loss: 0.1998 - regressor_output_loss: 0.0603 - val_loss: 1.0874 - val_discriminator_output_loss: 1.0262 - val_regressor_output_loss: 0.0611
# Epoch 58/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2628 - discriminator_output_loss: 0.2037 - regressor_output_loss: 0.0591 - val_loss: 1.0575 - val_discriminator_output_loss: 0.9921 - val_regressor_output_loss: 0.0654
# Epoch 59/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2527 - discriminator_output_loss: 0.1968 - regressor_output_loss: 0.0559 - val_loss: 1.1173 - val_discriminator_output_loss: 1.0568 - val_regressor_output_loss: 0.0605
# Epoch 60/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2617 - discriminator_output_loss: 0.2036 - regressor_output_loss: 0.0581 - val_loss: 1.0696 - val_discriminator_output_loss: 1.0137 - val_regressor_output_loss: 0.0560
# Epoch 61/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2654 - discriminator_output_loss: 0.2074 - regressor_output_loss: 0.0579 - val_loss: 1.0192 - val_discriminator_output_loss: 0.9840 - val_regressor_output_loss: 0.0352
# Epoch 62/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2711 - discriminator_output_loss: 0.2179 - regressor_output_loss: 0.0532 - val_loss: 1.0268 - val_discriminator_output_loss: 0.9793 - val_regressor_output_loss: 0.0476
# Epoch 63/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2473 - discriminator_output_loss: 0.1950 - regressor_output_loss: 0.0522 - val_loss: 1.0345 - val_discriminator_output_loss: 0.9920 - val_regressor_output_loss: 0.0425
# Epoch 64/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2700 - discriminator_output_loss: 0.2139 - regressor_output_loss: 0.0561 - val_loss: 1.0597 - val_discriminator_output_loss: 1.0337 - val_regressor_output_loss: 0.0260
# Epoch 65/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2676 - discriminator_output_loss: 0.2149 - regressor_output_loss: 0.0527 - val_loss: 1.0404 - val_discriminator_output_loss: 1.0219 - val_regressor_output_loss: 0.0184
# Epoch 66/1000
# 17/17 [==============================] - 2s 137ms/step - loss: 0.2596 - discriminator_output_loss: 0.2071 - regressor_output_loss: 0.0525 - val_loss: 1.1347 - val_discriminator_output_loss: 1.1183 - val_regressor_output_loss: 0.0164
# Epoch 67/1000
# 17/17 [==============================] - 2s 137ms/step - loss: 0.2623 - discriminator_output_loss: 0.2124 - regressor_output_loss: 0.0499 - val_loss: 1.0619 - val_discriminator_output_loss: 1.0499 - val_regressor_output_loss: 0.0121
# Epoch 68/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2738 - discriminator_output_loss: 0.2213 - regressor_output_loss: 0.0525 - val_loss: 1.0763 - val_discriminator_output_loss: 1.0493 - val_regressor_output_loss: 0.0270
# Epoch 69/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2689 - discriminator_output_loss: 0.2160 - regressor_output_loss: 0.0529 - val_loss: 1.0722 - val_discriminator_output_loss: 1.0536 - val_regressor_output_loss: 0.0186
# Epoch 70/1000
# 17/17 [==============================] - 2s 137ms/step - loss: 0.2636 - discriminator_output_loss: 0.2173 - regressor_output_loss: 0.0463 - val_loss: 1.1117 - val_discriminator_output_loss: 1.1007 - val_regressor_output_loss: 0.0110
# Epoch 71/1000
# 17/17 [==============================] - 2s 137ms/step - loss: 0.2733 - discriminator_output_loss: 0.2237 - regressor_output_loss: 0.0496 - val_loss: 1.2039 - val_discriminator_output_loss: 1.1945 - val_regressor_output_loss: 0.0094
# Epoch 72/1000
# 17/17 [==============================] - 2s 137ms/step - loss: 0.2777 - discriminator_output_loss: 0.2320 - regressor_output_loss: 0.0457 - val_loss: 1.1561 - val_discriminator_output_loss: 1.1502 - val_regressor_output_loss: 0.0059
# Epoch 73/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2701 - discriminator_output_loss: 0.2220 - regressor_output_loss: 0.0481 - val_loss: 1.2895 - val_discriminator_output_loss: 1.2828 - val_regressor_output_loss: 0.0067
# Epoch 74/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2808 - discriminator_output_loss: 0.2332 - regressor_output_loss: 0.0477 - val_loss: 1.3762 - val_discriminator_output_loss: 1.3676 - val_regressor_output_loss: 0.0087
# Epoch 75/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2738 - discriminator_output_loss: 0.2302 - regressor_output_loss: 0.0436 - val_loss: 1.3105 - val_discriminator_output_loss: 1.2976 - val_regressor_output_loss: 0.0129
# Epoch 76/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2647 - discriminator_output_loss: 0.2194 - regressor_output_loss: 0.0453 - val_loss: 1.4370 - val_discriminator_output_loss: 1.4198 - val_regressor_output_loss: 0.0173
# Epoch 77/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2668 - discriminator_output_loss: 0.2250 - regressor_output_loss: 0.0418 - val_loss: 1.3525 - val_discriminator_output_loss: 1.3378 - val_regressor_output_loss: 0.0147
# Epoch 78/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2622 - discriminator_output_loss: 0.2201 - regressor_output_loss: 0.0421 - val_loss: 1.5095 - val_discriminator_output_loss: 1.4936 - val_regressor_output_loss: 0.0159
# Epoch 79/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2668 - discriminator_output_loss: 0.2213 - regressor_output_loss: 0.0456 - val_loss: 1.5420 - val_discriminator_output_loss: 1.5200 - val_regressor_output_loss: 0.0221
# Epoch 80/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2650 - discriminator_output_loss: 0.2219 - regressor_output_loss: 0.0431 - val_loss: 1.9308 - val_discriminator_output_loss: 1.9021 - val_regressor_output_loss: 0.0287
# Epoch 81/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2673 - discriminator_output_loss: 0.2273 - regressor_output_loss: 0.0399 - val_loss: 1.9795 - val_discriminator_output_loss: 1.9491 - val_regressor_output_loss: 0.0304
# Epoch 82/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2722 - discriminator_output_loss: 0.2301 - regressor_output_loss: 0.0421 - val_loss: 2.1086 - val_discriminator_output_loss: 2.0383 - val_regressor_output_loss: 0.0703
# Epoch 83/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2735 - discriminator_output_loss: 0.2338 - regressor_output_loss: 0.0397 - val_loss: 2.3120 - val_discriminator_output_loss: 2.2020 - val_regressor_output_loss: 0.1100
# Epoch 84/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2664 - discriminator_output_loss: 0.2274 - regressor_output_loss: 0.0390 - val_loss: 2.1480 - val_discriminator_output_loss: 2.0672 - val_regressor_output_loss: 0.0807
# Epoch 85/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2567 - discriminator_output_loss: 0.2192 - regressor_output_loss: 0.0374 - val_loss: 2.2408 - val_discriminator_output_loss: 2.2037 - val_regressor_output_loss: 0.0371
# Epoch 86/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2502 - discriminator_output_loss: 0.2126 - regressor_output_loss: 0.0376 - val_loss: 2.1327 - val_discriminator_output_loss: 2.0924 - val_regressor_output_loss: 0.0403
# Epoch 87/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.2578 - discriminator_output_loss: 0.2218 - regressor_output_loss: 0.0360 - val_loss: 2.2673 - val_discriminator_output_loss: 2.2343 - val_regressor_output_loss: 0.0330
# Epoch 88/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2408 - discriminator_output_loss: 0.2039 - regressor_output_loss: 0.0368 - val_loss: 2.2416 - val_discriminator_output_loss: 2.2061 - val_regressor_output_loss: 0.0355
# Epoch 89/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2279 - discriminator_output_loss: 0.1898 - regressor_output_loss: 0.0381 - val_loss: 2.2493 - val_discriminator_output_loss: 2.2232 - val_regressor_output_loss: 0.0261
# Epoch 90/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2316 - discriminator_output_loss: 0.1933 - regressor_output_loss: 0.0383 - val_loss: 2.3055 - val_discriminator_output_loss: 2.2919 - val_regressor_output_loss: 0.0136
# Epoch 91/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2508 - discriminator_output_loss: 0.2133 - regressor_output_loss: 0.0375 - val_loss: 2.1527 - val_discriminator_output_loss: 2.1441 - val_regressor_output_loss: 0.0086
# Epoch 92/1000
# 17/17 [==============================] - 2s 137ms/step - loss: 0.2697 - discriminator_output_loss: 0.2345 - regressor_output_loss: 0.0351 - val_loss: 2.3123 - val_discriminator_output_loss: 2.3064 - val_regressor_output_loss: 0.0059
# Epoch 93/1000
# 17/17 [==============================] - 2s 138ms/step - loss: 0.2705 - discriminator_output_loss: 0.2334 - regressor_output_loss: 0.0371 - val_loss: 2.1251 - val_discriminator_output_loss: 2.1207 - val_regressor_output_loss: 0.0044
# Epoch 94/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2902 - discriminator_output_loss: 0.2552 - regressor_output_loss: 0.0350 - val_loss: 1.9429 - val_discriminator_output_loss: 1.9375 - val_regressor_output_loss: 0.0053
# Epoch 95/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3104 - discriminator_output_loss: 0.2726 - regressor_output_loss: 0.0378 - val_loss: 1.8419 - val_discriminator_output_loss: 1.8233 - val_regressor_output_loss: 0.0186
# Epoch 96/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3484 - discriminator_output_loss: 0.3154 - regressor_output_loss: 0.0329 - val_loss: 1.7693 - val_discriminator_output_loss: 1.7411 - val_regressor_output_loss: 0.0282
# Epoch 97/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3527 - discriminator_output_loss: 0.3190 - regressor_output_loss: 0.0338 - val_loss: 1.4256 - val_discriminator_output_loss: 1.4000 - val_regressor_output_loss: 0.0256
# Epoch 98/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3620 - discriminator_output_loss: 0.3305 - regressor_output_loss: 0.0315 - val_loss: 0.9754 - val_discriminator_output_loss: 0.9578 - val_regressor_output_loss: 0.0177
# Epoch 99/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3504 - discriminator_output_loss: 0.3160 - regressor_output_loss: 0.0344 - val_loss: 1.2487 - val_discriminator_output_loss: 1.2143 - val_regressor_output_loss: 0.0345
# Epoch 100/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2944 - discriminator_output_loss: 0.2619 - regressor_output_loss: 0.0326 - val_loss: 1.0880 - val_discriminator_output_loss: 1.0611 - val_regressor_output_loss: 0.0270
# Epoch 101/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2319 - discriminator_output_loss: 0.2018 - regressor_output_loss: 0.0301 - val_loss: 1.2873 - val_discriminator_output_loss: 1.2555 - val_regressor_output_loss: 0.0318
# Epoch 102/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2499 - discriminator_output_loss: 0.2185 - regressor_output_loss: 0.0314 - val_loss: 1.9196 - val_discriminator_output_loss: 1.8096 - val_regressor_output_loss: 0.1100
# Epoch 103/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2905 - discriminator_output_loss: 0.2568 - regressor_output_loss: 0.0337 - val_loss: 2.6378 - val_discriminator_output_loss: 2.5877 - val_regressor_output_loss: 0.0501
# Epoch 104/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2991 - discriminator_output_loss: 0.2697 - regressor_output_loss: 0.0293 - val_loss: 2.1769 - val_discriminator_output_loss: 2.1669 - val_regressor_output_loss: 0.0101
# Epoch 105/1000
# 17/17 [==============================] - 2s 131ms/step - loss: 0.2817 - discriminator_output_loss: 0.2531 - regressor_output_loss: 0.0286 - val_loss: 2.2610 - val_discriminator_output_loss: 2.2450 - val_regressor_output_loss: 0.0159
# Epoch 106/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2639 - discriminator_output_loss: 0.2341 - regressor_output_loss: 0.0298 - val_loss: 1.8198 - val_discriminator_output_loss: 1.7669 - val_regressor_output_loss: 0.0530
# Epoch 107/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2540 - discriminator_output_loss: 0.2246 - regressor_output_loss: 0.0294 - val_loss: 1.4650 - val_discriminator_output_loss: 1.4557 - val_regressor_output_loss: 0.0094
# Epoch 108/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3292 - discriminator_output_loss: 0.2947 - regressor_output_loss: 0.0344 - val_loss: 1.4654 - val_discriminator_output_loss: 1.3464 - val_regressor_output_loss: 0.1190
# Epoch 109/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2932 - discriminator_output_loss: 0.2535 - regressor_output_loss: 0.0397 - val_loss: 1.5479 - val_discriminator_output_loss: 1.4137 - val_regressor_output_loss: 0.1342
# Epoch 110/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2340 - discriminator_output_loss: 0.1986 - regressor_output_loss: 0.0355 - val_loss: 1.4057 - val_discriminator_output_loss: 1.2379 - val_regressor_output_loss: 0.1678
# Epoch 111/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2306 - discriminator_output_loss: 0.2002 - regressor_output_loss: 0.0304 - val_loss: 1.0230 - val_discriminator_output_loss: 1.0160 - val_regressor_output_loss: 0.0069
# Epoch 112/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3056 - discriminator_output_loss: 0.2750 - regressor_output_loss: 0.0306 - val_loss: 2.6224 - val_discriminator_output_loss: 2.2401 - val_regressor_output_loss: 0.3823
# Epoch 113/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3234 - discriminator_output_loss: 0.2922 - regressor_output_loss: 0.0312 - val_loss: 1.6357 - val_discriminator_output_loss: 1.3182 - val_regressor_output_loss: 0.3175
# Epoch 114/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3356 - discriminator_output_loss: 0.3063 - regressor_output_loss: 0.0292 - val_loss: 1.4579 - val_discriminator_output_loss: 1.3615 - val_regressor_output_loss: 0.0964
# Epoch 115/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3221 - discriminator_output_loss: 0.2956 - regressor_output_loss: 0.0265 - val_loss: 1.6374 - val_discriminator_output_loss: 1.6026 - val_regressor_output_loss: 0.0348
# Epoch 116/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2671 - discriminator_output_loss: 0.2393 - regressor_output_loss: 0.0278 - val_loss: 1.7249 - val_discriminator_output_loss: 1.6281 - val_regressor_output_loss: 0.0968
# Epoch 117/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3513 - discriminator_output_loss: 0.3226 - regressor_output_loss: 0.0287 - val_loss: 1.7713 - val_discriminator_output_loss: 1.7303 - val_regressor_output_loss: 0.0410
# Epoch 118/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.4051 - discriminator_output_loss: 0.3769 - regressor_output_loss: 0.0282 - val_loss: 1.3574 - val_discriminator_output_loss: 1.2639 - val_regressor_output_loss: 0.0935
# Epoch 119/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3430 - discriminator_output_loss: 0.3180 - regressor_output_loss: 0.0250 - val_loss: 1.2284 - val_discriminator_output_loss: 1.0180 - val_regressor_output_loss: 0.2104
# Epoch 120/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2504 - discriminator_output_loss: 0.2272 - regressor_output_loss: 0.0232 - val_loss: 1.4256 - val_discriminator_output_loss: 1.2644 - val_regressor_output_loss: 0.1612
# Epoch 121/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3665 - discriminator_output_loss: 0.3362 - regressor_output_loss: 0.0303 - val_loss: 1.2816 - val_discriminator_output_loss: 1.0592 - val_regressor_output_loss: 0.2224
# Epoch 122/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3537 - discriminator_output_loss: 0.3241 - regressor_output_loss: 0.0295 - val_loss: 1.6547 - val_discriminator_output_loss: 1.4297 - val_regressor_output_loss: 0.2250
# Epoch 123/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2785 - discriminator_output_loss: 0.2527 - regressor_output_loss: 0.0257 - val_loss: 1.7568 - val_discriminator_output_loss: 1.6735 - val_regressor_output_loss: 0.0832
# Epoch 124/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2913 - discriminator_output_loss: 0.2671 - regressor_output_loss: 0.0242 - val_loss: 1.9315 - val_discriminator_output_loss: 1.8861 - val_regressor_output_loss: 0.0453
# Epoch 125/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2525 - discriminator_output_loss: 0.2271 - regressor_output_loss: 0.0254 - val_loss: 2.0847 - val_discriminator_output_loss: 2.0295 - val_regressor_output_loss: 0.0552
# Epoch 126/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2341 - discriminator_output_loss: 0.2106 - regressor_output_loss: 0.0235 - val_loss: 2.0580 - val_discriminator_output_loss: 2.0211 - val_regressor_output_loss: 0.0369
# Epoch 127/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2584 - discriminator_output_loss: 0.2345 - regressor_output_loss: 0.0239 - val_loss: 2.3068 - val_discriminator_output_loss: 2.2936 - val_regressor_output_loss: 0.0132
# Epoch 128/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2527 - discriminator_output_loss: 0.2298 - regressor_output_loss: 0.0230 - val_loss: 1.9394 - val_discriminator_output_loss: 1.8532 - val_regressor_output_loss: 0.0862
# Epoch 129/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2628 - discriminator_output_loss: 0.2401 - regressor_output_loss: 0.0226 - val_loss: 1.9403 - val_discriminator_output_loss: 1.7432 - val_regressor_output_loss: 0.1971
# Epoch 130/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3277 - discriminator_output_loss: 0.3023 - regressor_output_loss: 0.0254 - val_loss: 2.1685 - val_discriminator_output_loss: 1.8786 - val_regressor_output_loss: 0.2899
# Epoch 131/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.4004 - discriminator_output_loss: 0.3758 - regressor_output_loss: 0.0246 - val_loss: 1.3632 - val_discriminator_output_loss: 1.2653 - val_regressor_output_loss: 0.0979
# Epoch 132/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3970 - discriminator_output_loss: 0.3724 - regressor_output_loss: 0.0246 - val_loss: 1.4924 - val_discriminator_output_loss: 1.3824 - val_regressor_output_loss: 0.1100
# Epoch 133/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.1740 - discriminator_output_loss: 0.1510 - regressor_output_loss: 0.0230 - val_loss: 1.5443 - val_discriminator_output_loss: 1.4045 - val_regressor_output_loss: 0.1399
# Epoch 134/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.1999 - discriminator_output_loss: 0.1765 - regressor_output_loss: 0.0235 - val_loss: 1.3393 - val_discriminator_output_loss: 1.3321 - val_regressor_output_loss: 0.0072
# Epoch 135/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2589 - discriminator_output_loss: 0.2356 - regressor_output_loss: 0.0233 - val_loss: 1.5194 - val_discriminator_output_loss: 1.5053 - val_regressor_output_loss: 0.0140
# Epoch 136/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2643 - discriminator_output_loss: 0.2419 - regressor_output_loss: 0.0224 - val_loss: 1.9919 - val_discriminator_output_loss: 1.9745 - val_regressor_output_loss: 0.0174
# Epoch 137/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2887 - discriminator_output_loss: 0.2650 - regressor_output_loss: 0.0238 - val_loss: 2.3675 - val_discriminator_output_loss: 2.3480 - val_regressor_output_loss: 0.0195
# Epoch 138/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3084 - discriminator_output_loss: 0.2862 - regressor_output_loss: 0.0222 - val_loss: 2.1694 - val_discriminator_output_loss: 2.0901 - val_regressor_output_loss: 0.0793
# Epoch 139/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2517 - discriminator_output_loss: 0.2305 - regressor_output_loss: 0.0212 - val_loss: 1.9608 - val_discriminator_output_loss: 1.8318 - val_regressor_output_loss: 0.1290
# Epoch 140/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2143 - discriminator_output_loss: 0.1928 - regressor_output_loss: 0.0215 - val_loss: 2.0433 - val_discriminator_output_loss: 1.8804 - val_regressor_output_loss: 0.1629
# Epoch 141/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2315 - discriminator_output_loss: 0.2090 - regressor_output_loss: 0.0225 - val_loss: 2.1979 - val_discriminator_output_loss: 2.0483 - val_regressor_output_loss: 0.1496
# Epoch 142/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2789 - discriminator_output_loss: 0.2547 - regressor_output_loss: 0.0242 - val_loss: 1.8710 - val_discriminator_output_loss: 1.7462 - val_regressor_output_loss: 0.1248
# Epoch 143/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.4162 - discriminator_output_loss: 0.3837 - regressor_output_loss: 0.0325 - val_loss: 1.0705 - val_discriminator_output_loss: 0.9614 - val_regressor_output_loss: 0.1091
# Epoch 144/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3649 - discriminator_output_loss: 0.3362 - regressor_output_loss: 0.0287 - val_loss: 1.0388 - val_discriminator_output_loss: 0.9227 - val_regressor_output_loss: 0.1161
# Epoch 145/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2613 - discriminator_output_loss: 0.2304 - regressor_output_loss: 0.0309 - val_loss: 1.1972 - val_discriminator_output_loss: 1.1649 - val_regressor_output_loss: 0.0323
# Epoch 146/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2832 - discriminator_output_loss: 0.2562 - regressor_output_loss: 0.0270 - val_loss: 0.9697 - val_discriminator_output_loss: 0.9545 - val_regressor_output_loss: 0.0153
# Epoch 147/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3128 - discriminator_output_loss: 0.2851 - regressor_output_loss: 0.0277 - val_loss: 1.1769 - val_discriminator_output_loss: 1.1705 - val_regressor_output_loss: 0.0064
# Epoch 148/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2722 - discriminator_output_loss: 0.2465 - regressor_output_loss: 0.0256 - val_loss: 1.7883 - val_discriminator_output_loss: 1.7581 - val_regressor_output_loss: 0.0302
# Epoch 149/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.1863 - discriminator_output_loss: 0.1603 - regressor_output_loss: 0.0260 - val_loss: 1.3546 - val_discriminator_output_loss: 1.3498 - val_regressor_output_loss: 0.0048
# Epoch 150/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.1796 - discriminator_output_loss: 0.1527 - regressor_output_loss: 0.0269 - val_loss: 0.8451 - val_discriminator_output_loss: 0.7784 - val_regressor_output_loss: 0.0667
# Epoch 151/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2212 - discriminator_output_loss: 0.1931 - regressor_output_loss: 0.0281 - val_loss: 0.9930 - val_discriminator_output_loss: 0.6988 - val_regressor_output_loss: 0.2942
# Epoch 152/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2726 - discriminator_output_loss: 0.2447 - regressor_output_loss: 0.0278 - val_loss: 1.1625 - val_discriminator_output_loss: 0.7604 - val_regressor_output_loss: 0.4021
# Epoch 153/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3733 - discriminator_output_loss: 0.3439 - regressor_output_loss: 0.0294 - val_loss: 1.6378 - val_discriminator_output_loss: 1.2213 - val_regressor_output_loss: 0.4165
# Epoch 154/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.4593 - discriminator_output_loss: 0.4341 - regressor_output_loss: 0.0253 - val_loss: 1.2499 - val_discriminator_output_loss: 1.1231 - val_regressor_output_loss: 0.1267
# Epoch 155/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.5076 - discriminator_output_loss: 0.4835 - regressor_output_loss: 0.0241 - val_loss: 1.3185 - val_discriminator_output_loss: 1.2760 - val_regressor_output_loss: 0.0425
# Epoch 156/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3903 - discriminator_output_loss: 0.3674 - regressor_output_loss: 0.0229 - val_loss: 1.5376 - val_discriminator_output_loss: 1.4820 - val_regressor_output_loss: 0.0556
# Epoch 157/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2986 - discriminator_output_loss: 0.2755 - regressor_output_loss: 0.0231 - val_loss: 2.0268 - val_discriminator_output_loss: 2.0015 - val_regressor_output_loss: 0.0253
# Epoch 158/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3807 - discriminator_output_loss: 0.3600 - regressor_output_loss: 0.0207 - val_loss: 2.3235 - val_discriminator_output_loss: 2.2952 - val_regressor_output_loss: 0.0283
# Epoch 159/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.4270 - discriminator_output_loss: 0.4082 - regressor_output_loss: 0.0188 - val_loss: 1.4198 - val_discriminator_output_loss: 1.3806 - val_regressor_output_loss: 0.0392
# Epoch 160/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3928 - discriminator_output_loss: 0.3699 - regressor_output_loss: 0.0229 - val_loss: 1.1886 - val_discriminator_output_loss: 1.1607 - val_regressor_output_loss: 0.0279
# Epoch 161/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3313 - discriminator_output_loss: 0.3078 - regressor_output_loss: 0.0235 - val_loss: 1.1057 - val_discriminator_output_loss: 1.0544 - val_regressor_output_loss: 0.0513
# Epoch 162/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3235 - discriminator_output_loss: 0.2974 - regressor_output_loss: 0.0260 - val_loss: 1.4053 - val_discriminator_output_loss: 1.2538 - val_regressor_output_loss: 0.1515
# Epoch 163/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3188 - discriminator_output_loss: 0.2953 - regressor_output_loss: 0.0235 - val_loss: 1.4636 - val_discriminator_output_loss: 1.2312 - val_regressor_output_loss: 0.2325
# Epoch 164/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3539 - discriminator_output_loss: 0.3312 - regressor_output_loss: 0.0227 - val_loss: 1.5321 - val_discriminator_output_loss: 1.2976 - val_regressor_output_loss: 0.2345
# Epoch 165/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.4408 - discriminator_output_loss: 0.4167 - regressor_output_loss: 0.0240 - val_loss: 1.8790 - val_discriminator_output_loss: 1.7089 - val_regressor_output_loss: 0.1701
# Epoch 166/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3617 - discriminator_output_loss: 0.3389 - regressor_output_loss: 0.0228 - val_loss: 1.5923 - val_discriminator_output_loss: 1.4573 - val_regressor_output_loss: 0.1350
# Epoch 167/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2455 - discriminator_output_loss: 0.2253 - regressor_output_loss: 0.0202 - val_loss: 1.1233 - val_discriminator_output_loss: 1.1018 - val_regressor_output_loss: 0.0216
# Epoch 168/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2407 - discriminator_output_loss: 0.2206 - regressor_output_loss: 0.0201 - val_loss: 1.3613 - val_discriminator_output_loss: 1.3508 - val_regressor_output_loss: 0.0105
# Epoch 169/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.4069 - discriminator_output_loss: 0.3883 - regressor_output_loss: 0.0186 - val_loss: 1.3534 - val_discriminator_output_loss: 1.3367 - val_regressor_output_loss: 0.0167
# Epoch 170/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.4358 - discriminator_output_loss: 0.4179 - regressor_output_loss: 0.0178 - val_loss: 1.2424 - val_discriminator_output_loss: 1.1894 - val_regressor_output_loss: 0.0530
# Epoch 171/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3533 - discriminator_output_loss: 0.3322 - regressor_output_loss: 0.0211 - val_loss: 1.7434 - val_discriminator_output_loss: 1.6164 - val_regressor_output_loss: 0.1270
# Epoch 172/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2787 - discriminator_output_loss: 0.2564 - regressor_output_loss: 0.0222 - val_loss: 1.5939 - val_discriminator_output_loss: 1.4547 - val_regressor_output_loss: 0.1392
# Epoch 173/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2703 - discriminator_output_loss: 0.2505 - regressor_output_loss: 0.0198 - val_loss: 1.6225 - val_discriminator_output_loss: 1.4777 - val_regressor_output_loss: 0.1448
# Epoch 174/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3024 - discriminator_output_loss: 0.2839 - regressor_output_loss: 0.0185 - val_loss: 1.3741 - val_discriminator_output_loss: 1.3624 - val_regressor_output_loss: 0.0117
# Epoch 175/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3776 - discriminator_output_loss: 0.3600 - regressor_output_loss: 0.0177 - val_loss: 1.1289 - val_discriminator_output_loss: 1.1206 - val_regressor_output_loss: 0.0083
# Epoch 176/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3970 - discriminator_output_loss: 0.3793 - regressor_output_loss: 0.0177 - val_loss: 1.6602 - val_discriminator_output_loss: 1.5926 - val_regressor_output_loss: 0.0676
# Epoch 177/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3071 - discriminator_output_loss: 0.2871 - regressor_output_loss: 0.0200 - val_loss: 1.7192 - val_discriminator_output_loss: 1.6526 - val_regressor_output_loss: 0.0667
# Epoch 178/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2180 - discriminator_output_loss: 0.1981 - regressor_output_loss: 0.0199 - val_loss: 1.9628 - val_discriminator_output_loss: 1.8626 - val_regressor_output_loss: 0.1001
# Epoch 179/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2273 - discriminator_output_loss: 0.2057 - regressor_output_loss: 0.0216 - val_loss: 1.8538 - val_discriminator_output_loss: 1.7937 - val_regressor_output_loss: 0.0601
# Epoch 180/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3101 - discriminator_output_loss: 0.2851 - regressor_output_loss: 0.0250 - val_loss: 1.2658 - val_discriminator_output_loss: 1.2214 - val_regressor_output_loss: 0.0444
# Epoch 181/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3951 - discriminator_output_loss: 0.3737 - regressor_output_loss: 0.0214 - val_loss: 1.0818 - val_discriminator_output_loss: 1.0283 - val_regressor_output_loss: 0.0535
# Epoch 182/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.5504 - discriminator_output_loss: 0.5325 - regressor_output_loss: 0.0179 - val_loss: 0.8557 - val_discriminator_output_loss: 0.8419 - val_regressor_output_loss: 0.0138
# Epoch 183/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.5596 - discriminator_output_loss: 0.5415 - regressor_output_loss: 0.0182 - val_loss: 1.5643 - val_discriminator_output_loss: 1.5464 - val_regressor_output_loss: 0.0179
# Epoch 184/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.4057 - discriminator_output_loss: 0.3884 - regressor_output_loss: 0.0173 - val_loss: 1.0961 - val_discriminator_output_loss: 1.0764 - val_regressor_output_loss: 0.0197
# Epoch 185/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3860 - discriminator_output_loss: 0.3701 - regressor_output_loss: 0.0160 - val_loss: 1.6470 - val_discriminator_output_loss: 1.5279 - val_regressor_output_loss: 0.1191
# Epoch 186/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.3718 - discriminator_output_loss: 0.3541 - regressor_output_loss: 0.0178 - val_loss: 1.8246 - val_discriminator_output_loss: 1.6996 - val_regressor_output_loss: 0.1250
# Epoch 187/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3905 - discriminator_output_loss: 0.3721 - regressor_output_loss: 0.0184 - val_loss: 1.7174 - val_discriminator_output_loss: 1.4903 - val_regressor_output_loss: 0.2271
# Epoch 188/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.4143 - discriminator_output_loss: 0.3940 - regressor_output_loss: 0.0203 - val_loss: 1.7739 - val_discriminator_output_loss: 1.6936 - val_regressor_output_loss: 0.0803
# Epoch 189/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2703 - discriminator_output_loss: 0.2461 - regressor_output_loss: 0.0241 - val_loss: 1.8320 - val_discriminator_output_loss: 1.7570 - val_regressor_output_loss: 0.0750
# Epoch 190/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.2089 - discriminator_output_loss: 0.1815 - regressor_output_loss: 0.0273 - val_loss: 1.7615 - val_discriminator_output_loss: 1.7112 - val_regressor_output_loss: 0.0503
# Epoch 191/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.2316 - discriminator_output_loss: 0.2049 - regressor_output_loss: 0.0267 - val_loss: 1.0060 - val_discriminator_output_loss: 0.9501 - val_regressor_output_loss: 0.0559
# Epoch 192/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.3583 - discriminator_output_loss: 0.3299 - regressor_output_loss: 0.0284 - val_loss: 1.0722 - val_discriminator_output_loss: 0.9446 - val_regressor_output_loss: 0.1276
# Epoch 193/1000
# ...
# Epoch 937/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 6.9609 - val_discriminator_output_loss: 6.9588 - val_regressor_output_loss: 0.0021
# Epoch 938/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.0813 - val_discriminator_output_loss: 7.0780 - val_regressor_output_loss: 0.0033
# Epoch 939/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.0751 - val_discriminator_output_loss: 7.0738 - val_regressor_output_loss: 0.0014
# Epoch 940/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.0966 - val_discriminator_output_loss: 7.0953 - val_regressor_output_loss: 0.0013
# Epoch 941/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.1216 - val_discriminator_output_loss: 7.1200 - val_regressor_output_loss: 0.0016
# Epoch 942/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.1661 - val_discriminator_output_loss: 7.1638 - val_regressor_output_loss: 0.0023
# Epoch 943/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.1899 - val_discriminator_output_loss: 7.1883 - val_regressor_output_loss: 0.0016
# Epoch 944/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7390 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0016 - val_loss: 7.2134 - val_discriminator_output_loss: 7.2118 - val_regressor_output_loss: 0.0016
# Epoch 945/1000
# 17/17 [==============================] - 2s 135ms/step - loss: 0.7391 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0018 - val_loss: 7.3793 - val_discriminator_output_loss: 7.3771 - val_regressor_output_loss: 0.0022
# Epoch 946/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7390 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0016 - val_loss: 7.0812 - val_discriminator_output_loss: 7.0792 - val_regressor_output_loss: 0.0020
# Epoch 947/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7391 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0017 - val_loss: 7.1460 - val_discriminator_output_loss: 7.1432 - val_regressor_output_loss: 0.0028
# Epoch 948/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.1925 - val_discriminator_output_loss: 7.1899 - val_regressor_output_loss: 0.0026
# Epoch 949/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.2660 - val_discriminator_output_loss: 7.2648 - val_regressor_output_loss: 0.0012
# Epoch 950/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.2816 - val_discriminator_output_loss: 7.2768 - val_regressor_output_loss: 0.0048
# Epoch 951/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.2622 - val_discriminator_output_loss: 7.2601 - val_regressor_output_loss: 0.0021
# Epoch 952/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.2109 - val_discriminator_output_loss: 7.2096 - val_regressor_output_loss: 0.0013
# Epoch 953/1000
# 17/17 [==============================] - 2s 135ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.1862 - val_discriminator_output_loss: 7.1840 - val_regressor_output_loss: 0.0021
# Epoch 954/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0016 - val_loss: 7.2707 - val_discriminator_output_loss: 7.2692 - val_regressor_output_loss: 0.0014
# Epoch 955/1000
# 17/17 [==============================] - 2s 135ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.2946 - val_discriminator_output_loss: 7.2908 - val_regressor_output_loss: 0.0038
# Epoch 956/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.5096 - val_discriminator_output_loss: 7.5063 - val_regressor_output_loss: 0.0033
# Epoch 957/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7390 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0016 - val_loss: 7.4531 - val_discriminator_output_loss: 7.4506 - val_regressor_output_loss: 0.0025
# Epoch 958/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0016 - val_loss: 7.6279 - val_discriminator_output_loss: 7.6250 - val_regressor_output_loss: 0.0029
# Epoch 959/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.5798 - val_discriminator_output_loss: 7.5759 - val_regressor_output_loss: 0.0040
# Epoch 960/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0016 - val_loss: 7.4449 - val_discriminator_output_loss: 7.4436 - val_regressor_output_loss: 0.0013
# Epoch 961/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.4120 - val_discriminator_output_loss: 7.4097 - val_regressor_output_loss: 0.0023
# Epoch 962/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.3850 - val_discriminator_output_loss: 7.3834 - val_regressor_output_loss: 0.0016
# Epoch 963/1000
# 17/17 [==============================] - 2s 136ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.3396 - val_discriminator_output_loss: 7.3377 - val_regressor_output_loss: 0.0019
# Epoch 964/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.3232 - val_discriminator_output_loss: 7.3220 - val_regressor_output_loss: 0.0013
# Epoch 965/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7385 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0012 - val_loss: 7.3495 - val_discriminator_output_loss: 7.3485 - val_regressor_output_loss: 0.0011
# Epoch 966/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.4169 - val_discriminator_output_loss: 7.4157 - val_regressor_output_loss: 0.0012
# Epoch 967/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7390 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0016 - val_loss: 7.4334 - val_discriminator_output_loss: 7.4308 - val_regressor_output_loss: 0.0026
# Epoch 968/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0012 - val_loss: 7.4261 - val_discriminator_output_loss: 7.4241 - val_regressor_output_loss: 0.0020
# Epoch 969/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.3527 - val_discriminator_output_loss: 7.3512 - val_regressor_output_loss: 0.0015
# Epoch 970/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.3420 - val_discriminator_output_loss: 7.3377 - val_regressor_output_loss: 0.0043
# Epoch 971/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.3100 - val_discriminator_output_loss: 7.3075 - val_regressor_output_loss: 0.0025
# Epoch 972/1000
# 17/17 [==============================] - 2s 135ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0012 - val_loss: 7.3500 - val_discriminator_output_loss: 7.3475 - val_regressor_output_loss: 0.0024
# Epoch 973/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.4295 - val_discriminator_output_loss: 7.4241 - val_regressor_output_loss: 0.0054
# Epoch 974/1000
# 17/17 [==============================] - 2s 132ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.3274 - val_discriminator_output_loss: 7.3254 - val_regressor_output_loss: 0.0020
# Epoch 975/1000
# 17/17 [==============================] - 2s 135ms/step - loss: 0.7385 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0012 - val_loss: 7.4270 - val_discriminator_output_loss: 7.4253 - val_regressor_output_loss: 0.0018
# Epoch 976/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.3348 - val_discriminator_output_loss: 7.3335 - val_regressor_output_loss: 0.0012
# Epoch 977/1000
# 17/17 [==============================] - 2s 135ms/step - loss: 0.7391 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0017 - val_loss: 7.3477 - val_discriminator_output_loss: 7.3452 - val_regressor_output_loss: 0.0025
# Epoch 978/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.3799 - val_discriminator_output_loss: 7.3784 - val_regressor_output_loss: 0.0015
# Epoch 979/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0012 - val_loss: 7.4340 - val_discriminator_output_loss: 7.4326 - val_regressor_output_loss: 0.0014
# Epoch 980/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.4768 - val_discriminator_output_loss: 7.4756 - val_regressor_output_loss: 0.0012
# Epoch 981/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.4832 - val_discriminator_output_loss: 7.4818 - val_regressor_output_loss: 0.0014
# Epoch 982/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.5037 - val_discriminator_output_loss: 7.5024 - val_regressor_output_loss: 0.0013
# Epoch 983/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.5211 - val_discriminator_output_loss: 7.5190 - val_regressor_output_loss: 0.0021
# Epoch 984/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.5195 - val_discriminator_output_loss: 7.5172 - val_regressor_output_loss: 0.0023
# Epoch 985/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7385 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0012 - val_loss: 7.4331 - val_discriminator_output_loss: 7.4319 - val_regressor_output_loss: 0.0012
# Epoch 986/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7385 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0011 - val_loss: 7.4643 - val_discriminator_output_loss: 7.4627 - val_regressor_output_loss: 0.0016
# Epoch 987/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.4914 - val_discriminator_output_loss: 7.4892 - val_regressor_output_loss: 0.0022
# Epoch 988/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.5718 - val_discriminator_output_loss: 7.5682 - val_regressor_output_loss: 0.0036
# Epoch 989/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.5238 - val_discriminator_output_loss: 7.5216 - val_regressor_output_loss: 0.0022
# Epoch 990/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0012 - val_loss: 7.4436 - val_discriminator_output_loss: 7.4423 - val_regressor_output_loss: 0.0013
# Epoch 991/1000
# 17/17 [==============================] - 2s 135ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0012 - val_loss: 7.5307 - val_discriminator_output_loss: 7.5279 - val_regressor_output_loss: 0.0027
# Epoch 992/1000
# 17/17 [==============================] - 2s 137ms/step - loss: 0.7389 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0015 - val_loss: 7.6804 - val_discriminator_output_loss: 7.6767 - val_regressor_output_loss: 0.0036
# Epoch 993/1000
# 17/17 [==============================] - 2s 133ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.4140 - val_discriminator_output_loss: 7.4125 - val_regressor_output_loss: 0.0015
# Epoch 994/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7386 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0012 - val_loss: 7.3642 - val_discriminator_output_loss: 7.3628 - val_regressor_output_loss: 0.0014
# Epoch 995/1000
# 17/17 [==============================] - 2s 136ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.3218 - val_discriminator_output_loss: 7.3204 - val_regressor_output_loss: 0.0013
# Epoch 996/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.3445 - val_discriminator_output_loss: 7.3424 - val_regressor_output_loss: 0.0021
# Epoch 997/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.4047 - val_discriminator_output_loss: 7.4022 - val_regressor_output_loss: 0.0025
# Epoch 998/1000
# 17/17 [==============================] - 2s 135ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.4248 - val_discriminator_output_loss: 7.4229 - val_regressor_output_loss: 0.0018
# Epoch 999/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7387 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0013 - val_loss: 7.4577 - val_discriminator_output_loss: 7.4564 - val_regressor_output_loss: 0.0014
# Epoch 1000/1000
# 17/17 [==============================] - 2s 134ms/step - loss: 0.7388 - discriminator_output_loss: 0.7374 - regressor_output_loss: 0.0014 - val_loss: 7.4601 - val_discriminator_output_loss: 7.4583 - val_regressor_output_loss: 0.0019
# end time: 2422.73

# %%
source_only_model = load_model('./model_checkpoint/source_only.h5')
source_add_target_model = load_model('./model_checkpoint/source_add_target.h5')
dann_model = dann()
dann_model.load_weights('./model_checkpoint/dann.h5')

# %%
y_true,y_pred = show_predict(source_only_model,testX,testY)
y_true,y_pred = show_predict(source_only_model,testDX,testDY)
print()
y_true,y_pred = show_predict(source_add_target_model,testX,testY)
y_true,y_pred = show_predict(source_add_target_model,testDX,testDY)
print()
y_true,y_pred = show_predict(dann_model,testX,testY)
y_true,y_pred = show_predict(dann_model,testDX,testDY)
# Out:
# rmse: 0.02962912280870112
# mape: 2.8638191875979544
# rmse: 0.2544107955546259
# mape: 63.061599588523876
#
# rmse: 0.030405625849596395
# mape: 3.090631314490157
# rmse: 0.05974623895604496
# mape: 12.14602444853376
#
# rmse: 0.032440963543752754
# mape: 3.344246869604693
# rmse: 0.04365538301294332
# mape: 8.644036130160407

# %%
dann().summary()
# Out:
# Model: "functional_23"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, 32, 32, 32,  0
# __________________________________________________________________________________________________
# conv1 (Conv3D)                  (None, 30, 30, 30, 1 448         input_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 30, 30, 30, 1 64          conv1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_110 (LeakyReLU)     (None, 30, 30, 30, 1 0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv3D)                  (None, 28, 28, 28, 1 6928        leaky_re_lu_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 28, 28, 28, 1 64          conv2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_111 (LeakyReLU)     (None, 28, 28, 28, 1 0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# maxpooling1 (MaxPooling3D)      (None, 14, 14, 14, 1 0           leaky_re_lu_111[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 14, 14, 14, 1 0           maxpooling1[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv3D)                  (None, 12, 12, 12, 3 13856       dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 12, 12, 12, 3 128         conv3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_112 (LeakyReLU)     (None, 12, 12, 12, 3 0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv4 (Conv3D)                  (None, 10, 10, 10, 3 27680       leaky_re_lu_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 10, 10, 10, 3 128         conv4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_113 (LeakyReLU)     (None, 10, 10, 10, 3 0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# maxpooling2 (MaxPooling3D)      (None, 5, 5, 5, 32)  0           leaky_re_lu_113[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 5, 5, 5, 32)  0           maxpooling2[0][0]
# __________________________________________________________________________________________________
# conv5 (Conv3D)                  (None, 3, 3, 3, 64)  55360       dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 3, 3, 3, 64)  256         conv5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_114 (LeakyReLU)     (None, 3, 3, 3, 64)  0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 1728)         0           leaky_re_lu_114[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 2000)         3458000     flatten_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 2000)         8000        dense_60[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_115 (LeakyReLU)     (None, 2000)         0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 300)          600300      leaky_re_lu_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 300)          1200        dense_61[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_116 (LeakyReLU)     (None, 300)          0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 150)          45150       leaky_re_lu_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 150)          600         dense_62[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_117 (LeakyReLU)     (None, 150)          0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 20)           3020        leaky_re_lu_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 20)           80          dense_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_118 (LeakyReLU)     (None, 20)           0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 16)           336         leaky_re_lu_118[0][0]
# __________________________________________________________________________________________________
# gradient_reversal_layer_5 (Grad (None, 1728)         0           flatten_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 16)           64          dense_64[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 100)          172900      gradient_reversal_layer_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_119 (LeakyReLU)     (None, 16)           0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# discriminator_output (Dense)    (None, 2)            202         dense_65[0][0]
# __________________________________________________________________________________________________
# regressor_output (Dense)        (None, 1)            17          leaky_re_lu_119[0][0]
# ==================================================================================================
# Total params: 4,394,781
# Trainable params: 4,389,489
# Non-trainable params: 5,292
# __________________________________________________________________________________________________

# %%
batch_size = 64
dann_model = dann()
plot_model(dann_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
def show_predict(model,input,label):
  pred = model.predict(input)
  if len(pred)==2:
    pred=pred[1]
  print("rmse:",rmse2(pred,label))
  y_pred =scaler.inverse_transform(pred)
  y_true =scaler.inverse_transform(label)
  print("mape:",mape2(y_true,y_pred))
  return y_true,y_pred

# %%
model_dir = './model_checkpoint/'
model_name = 'dann_model'
mkdir(model_dir)

#hyperparameters
lr= 0.0001
bata_1= 0.9
batch_size= 64
epochs= 1000
patience = 500
loss ='mae'
savename =  model_dir+model_name+".h5"

early_stopping = EarlyStopping(monitor='loss',patience=patience)
cp_callback = ModelCheckpoint(filepath = savename,monitor='loss',save_best_only=True,save_weights_only=False)

adam=Adam(lr=lr)

dann_model = dann()
dann_model.compile(optimizer=Adam(lr=lr)
                  ,loss={'regressor_output': loss
                         ,'discriminator_output': 'binary_crossentropy'})

startTime = time.time()
x_train,y_train = combined_train_imgs,[combined_train_domain,combined_train_labels]
x_valid,y_valid = combined_test_imgs,[combined_test_domain,combined_test_labels]
hist = dann_model.fit(x_train,y_train
                 ,batch_size=batch_size
                 ,epochs= epochs
                 ,verbose= 1
                 ,validation_data =(x_valid,y_valid)
                 ,callbacks=[cp_callback, early_stopping])

endTime = time.time() - startTime
print("end time:",round(endTime,2))

# %%
#y_true,y_pred = show_predict(model,testX,testY)
y_true,y_pred = show_predict(model,testDX,testDY)
#y_true,y_pred = show_predict(source_add_target_model,testX,testY)
y_true,y_pred = show_predict(source_add_target_model,testDX,testDY)
#y_true,y_pred = show_predict(dann_model,testX,testY)
y_true,y_pred = show_predict(dann_model,testDX,testDY)
